# %% [markdown]
# # Headings

# %% [markdown]
# > Add # sign in front of phrase to create heading. There are six heading levels from H1 to H6
#
# ```
# # Heading level 1
# ## Heading level 2
# ### Heading level 3
# #### Heading level 4
# ##### Heading level 5
# ###### Heading level 6
# ```

# %% [markdown]
# # Blank line

# %% [markdown]
# > Use a blank line to separate one or more lines of text. (like TeX)
#
# I really like using Markdown.
#
# I think I'll use it from now on.

# %% [markdown]
# > End a line with two or more spaces, and then type Return/Enter
#
# I really like using Markdown.
# I think I'll use it from now on.

# %% [markdown]
# # Emphasis

# %% [markdown]
# ## Bold
# > Add 2 `*` or 2 `_` before **AND** after a word or phrase.
#
# I love **bold text**.
#
# I love __bold text__.
#
# Love **is** bold

# %% [markdown]
# ## Italic
# > Add 1 `*` or 1 `_` before **AND** after a word or phrase.
#
# I love *bold text*.
#
# I love _bold text_.
#
# Love *is* bold

# %% [markdown]
# ## Bold & Italic
# > Add 3 `*` or 3 `_` before **AND** after a word or phrase.
#
# I love ***bold text***.
#
# I love ___bold text___.
#
# Love ***is*** bold

# %% [markdown]
# ## Strikethrough
# > Add `~~` before **AND** after a word
#
# The world is ~~flat~~ round.

# %% [markdown]
# # Blockquotes

# %% [markdown]
# ## Single block-quote
# > Add a `>` in front of a paragraph.
#
# > Dorothy followed her through many rooms

# %% [markdown]
# ## Blockquotes with Multiple Paragraphs
# > Add a `>` on the blank lines between the paragraphs.
#
# > This the first paragraph.
# >
# > And this is the second paragraph.

# %% [markdown]
# # Listing

# %% [markdown]
# ## Ordered Lists
#
# > Add line items with numbers followed by periods. The numbers don’t have to be numerical order
#
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
#
#
# 1. First item
# 1. Second item
# 1. Third item
# 1. Fourth item
#
#
# 1. First item
# 8. Second item
# 3. Third item
# 5. Fourth item

# %% [markdown]
# ## Unordered Lists
# > add dashes (-), asterisks (*), or plus signs (+) in front of line items.
#
# - First item
# - Second item
# - Third item
# - Fourth item
#
#
# * First item
# * Second item
# * Third item
# * Fourth item
#
#
# + First item
# * Second item
# - Third item
# + Fourth item

# %% [markdown]
# ## Nesting List Items
# >  indent the items four spaces or one tab
#
# 1. First item
# 2. Second item
# 3. Third item
#     1. Indented item
#     2. Indented item
# 4. Fourth item

# %% [markdown]
# # Code

# %% [markdown]
# > Enclose it in tick marks (`)
#
# At the command prompt, type `nano`.

# %% [markdown]
# ## Escaping Tick Marks

# %% [markdown]
# If the word or phrase you want to denote as code includes one or more tick marks, you can escape it by enclosing the word or phrase in double tick marks ( ``)
#
# Use `code` in your Markdown file.
#
# ``Use `code` in your Markdown file.``
#
# ```Use ``code`` in your Markdown file.```

# %% [markdown]
# # Horizontal Rules/Line sketching

# %% [markdown]
# > Use >=3 asterisks (***), dashes (---), or underscores (___) on a line by themselves.
#
# ***
#
# ---
#
# ___

# %% [markdown]
# # Links/URLs

# %% [markdown]
# > Full-version: Write as `[Link text](Link URL "Title")`. Title is hover text of link
#
# Use [Duck Duck Go](https://duckduckgo.com "My search engine!").
#
#
#
# > Short-verson: Write as `[Link text]{Link URL}`
#
# Use [Duck Duck Go](https://duckduckgo.com).

# %% [markdown]
# ## URLs and Email
# To quickly turn a URL or email address into a link, enclose it in angle brackets
#
# <https://eff.org>
#
# <fake@example.com>

# %% [markdown]
# # Images

# %% [markdown]
# > Do as `![Caption](Image-url-or-link "Hover-text")`
#
# ![This is a nice caption](https://homepages.cae.wisc.edu/~ece533/images/airplane.png "A sample image of jet")

# %% [markdown]
# # Write special characters:

# %% [markdown]
# > Add a backslash (\) in front of the character.
#
# | Character | Name |
# |----|---|
# \ | backslash
# ` | tickmark
# * | asterisk
# _ | underscore
# {} | curly braces
# [] | brackets
# () | parentheses
# # | pound sign
# + | plus sign
# - | minus sign (hyphen)
# . | dot
# ! | exclamation mark
#
# This is asterisk \*

# %% [markdown]
# # Table

# %% [markdown]
# > To add a table, use `|-----------|` to create column header
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
